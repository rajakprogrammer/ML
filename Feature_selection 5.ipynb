# %%
import pandas as pd
import numpy as np
import time as t
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
dataframe_project = pd.read_csv(r'D:\College Education\Semester 5\19CSE305 Machine Learning\Project\Coding\patches_gabor_15816_1.csv')
dataframe_project
# Out:
#                    ImageName  LocalEnergy_0_1  LocalEnergy_0_2  \
# 0     MaI286_255.jpg_0_0.png          1607984           590161
# 1     MaI286_256.jpg_0_0.png          2409410           643821
# 2     MaI286_256.jpg_0_2.png          1244326           369812
# 3     MaI286_256.jpg_0_3.png          1631795           557097
# 4     MaI286_258.jpg_0_0.png           984212           433434
# ...                      ...              ...              ...
# 4305      MaI843_047_0_0.png          1148726           301551
# 4306      MaI843_048_0_1.png           645854           234329
# 4307      MaI843_048_0_0.png          3120475           666772
# 4308      MaI843_047_0_8.png          1277520           612085
# 4309      MaI843_049_0_0.png          2588477           663550
#
#       LocalEnergy_0_3  LocalEnergy_0.7853981633974483_1  \
# 0            30393367                          30586929
# 1            28341070                          27499264
# 2            30907068                          27466105
# 3            30301489                          29490085
# 4            29948438                          30600901
# ...               ...                               ...
# 4305         24516974                          27216360
# 4306         29333027                          29946293
# 4307         29133067                          29819972
# 4308         24686619                          27101002
# 4309         24945878                          27826266
#
#       LocalEnergy_0.7853981633974483_2  LocalEnergy_0.7853981633974483_3  \
# 0                             30908212                           3557712
# 1                             28892467                           3982411
# 2                             28429032                           2831793
# 3                             29306020                           4807170
# 4                             31128474                           2724761
# ...                                ...                               ...
# 4305                          30997331                           8563063
# 4306                          31494284                           6389616
# 4307                          30353781                           5961931
# 4308                          30589675                          10843015
# 4309                          30722393                           9020987
#
#       LocalEnergy_1.5707963267948966_1  LocalEnergy_1.5707963267948966_2  \
# 0                              1621138                            652953
# 1                              2402321                            644235
# 2                              1252555                            602900
# 3                              1644043                           1057676
# 4                               979870                            374437
# ...                                ...                               ...
# 4305                           1133933                            291160
# 4306                            634937                            464582
# 4307                           3086075                            357274
# 4308                           1271576                            646650
# 4309                           2577327                            397905
#
#       LocalEnergy_1.5707963267948966_3  ...  \
# 0                             29941573  ...
# 1                             27960356  ...
# 2                             30921587  ...
# 3                             29838689  ...
# 4                             30769862  ...
# ...                                ...  ...
# 4305                          24664964  ...
# 4306                          29331611  ...
# 4307                          29495865  ...
# 4308                          25356419  ...
# 4309                          25003415  ...
#
#       MeanAmplitude_0.7853981633974483_1  MeanAmplitude_0.7853981633974483_2  \
# 0                               42706367                            21992566
# 1                               45782802                            23562865
# 2                               45316007                            23315932
# 3                               41933519                            21616534
# 4                               43313769                            22282942
# ...                                  ...                                 ...
# 4305                            36116804                            18562491
# 4306                            40270695                            20714888
# 4307                            38812330                            19959629
# 4308                            35144094                            18084309
# 4309                            35094358                            18051221
#
#       MeanAmplitude_0.7853981633974483_3  MeanAmplitude_1.5707963267948966_1  \
# 0                               62263734                            65066148
# 1                               61063851                            64309685
# 2                               63392361                            65690131
# 3                               60989696                            65434755
# 4                               63965827                            66146550
# ...                                  ...                                 ...
# 4305                            61832379                            65723007
# 4306                            62239700                            66517727
# 4307                            59041573                            62365063
# 4308                            60155871                            66228896
# 4309                            58897115                            63528523
#
#       MeanAmplitude_1.5707963267948966_2  MeanAmplitude_1.5707963267948966_3  \
# 0                                 249147                            40622791
# 1                                 252989                            43541072
# 2                                 257766                            43109193
# 3                                 472186                            40035467
# 4                                 137173                            41167720
# ...                                  ...                                 ...
# 4305                               65218                            34301160
# 4306                              119120                            38264591
# 4307                               74478                            36842285
# 4308                              176590                            33418317
# 4309                               86045                            33316845
#
#       MeanAmplitude_2.356194490192345_1  MeanAmplitude_2.356194490192345_2  \
# 0                              42675142                           21954827
# 1                              45761590                           23541111
# 2                              45296517                           23293852
# 3                              41888839                           21567725
# 4                              43298158                           22265049
# ...                                 ...                                ...
# 4305                           36116430                           18561987
# 4306                           40266947                           20706356
# 4307                           38809960                           19953819
# 4308                           35146446                           18088530
# 4309                           35091896                           18046364
#
#       MeanAmplitude_2.356194490192345_3  class
# 0                              62367472   good
# 1                              61161404   good
# 2                              63474181   good
# 3                              61148415   good
# 4                              64010694   good
# ...                                 ...    ...
# 4305                           61803126    bad
# 4306                           62337197    bad
# 4307                           59094463    bad
# 4308                           60149050    bad
# 4309                           58902170    bad
#
# [4310 rows x 26 columns]

# %%
from sklearn import preprocessing as prep
label_encoder = prep.LabelEncoder()
dataframe_project['class'] = label_encoder.fit_transform(dataframe_project['class'])
dataframe_project
# Out:
#                    ImageName  LocalEnergy_0_1  LocalEnergy_0_2  \
# 0     MaI286_255.jpg_0_0.png          1607984           590161
# 1     MaI286_256.jpg_0_0.png          2409410           643821
# 2     MaI286_256.jpg_0_2.png          1244326           369812
# 3     MaI286_256.jpg_0_3.png          1631795           557097
# 4     MaI286_258.jpg_0_0.png           984212           433434
# ...                      ...              ...              ...
# 4305      MaI843_047_0_0.png          1148726           301551
# 4306      MaI843_048_0_1.png           645854           234329
# 4307      MaI843_048_0_0.png          3120475           666772
# 4308      MaI843_047_0_8.png          1277520           612085
# 4309      MaI843_049_0_0.png          2588477           663550
#
#       LocalEnergy_0_3  LocalEnergy_0.7853981633974483_1  \
# 0            30393367                          30586929
# 1            28341070                          27499264
# 2            30907068                          27466105
# 3            30301489                          29490085
# 4            29948438                          30600901
# ...               ...                               ...
# 4305         24516974                          27216360
# 4306         29333027                          29946293
# 4307         29133067                          29819972
# 4308         24686619                          27101002
# 4309         24945878                          27826266
#
#       LocalEnergy_0.7853981633974483_2  LocalEnergy_0.7853981633974483_3  \
# 0                             30908212                           3557712
# 1                             28892467                           3982411
# 2                             28429032                           2831793
# 3                             29306020                           4807170
# 4                             31128474                           2724761
# ...                                ...                               ...
# 4305                          30997331                           8563063
# 4306                          31494284                           6389616
# 4307                          30353781                           5961931
# 4308                          30589675                          10843015
# 4309                          30722393                           9020987
#
#       LocalEnergy_1.5707963267948966_1  LocalEnergy_1.5707963267948966_2  \
# 0                              1621138                            652953
# 1                              2402321                            644235
# 2                              1252555                            602900
# 3                              1644043                           1057676
# 4                               979870                            374437
# ...                                ...                               ...
# 4305                           1133933                            291160
# 4306                            634937                            464582
# 4307                           3086075                            357274
# 4308                           1271576                            646650
# 4309                           2577327                            397905
#
#       LocalEnergy_1.5707963267948966_3  ...  \
# 0                             29941573  ...
# 1                             27960356  ...
# 2                             30921587  ...
# 3                             29838689  ...
# 4                             30769862  ...
# ...                                ...  ...
# 4305                          24664964  ...
# 4306                          29331611  ...
# 4307                          29495865  ...
# 4308                          25356419  ...
# 4309                          25003415  ...
#
#       MeanAmplitude_0.7853981633974483_1  MeanAmplitude_0.7853981633974483_2  \
# 0                               42706367                            21992566
# 1                               45782802                            23562865
# 2                               45316007                            23315932
# 3                               41933519                            21616534
# 4                               43313769                            22282942
# ...                                  ...                                 ...
# 4305                            36116804                            18562491
# 4306                            40270695                            20714888
# 4307                            38812330                            19959629
# 4308                            35144094                            18084309
# 4309                            35094358                            18051221
#
#       MeanAmplitude_0.7853981633974483_3  MeanAmplitude_1.5707963267948966_1  \
# 0                               62263734                            65066148
# 1                               61063851                            64309685
# 2                               63392361                            65690131
# 3                               60989696                            65434755
# 4                               63965827                            66146550
# ...                                  ...                                 ...
# 4305                            61832379                            65723007
# 4306                            62239700                            66517727
# 4307                            59041573                            62365063
# 4308                            60155871                            66228896
# 4309                            58897115                            63528523
#
#       MeanAmplitude_1.5707963267948966_2  MeanAmplitude_1.5707963267948966_3  \
# 0                                 249147                            40622791
# 1                                 252989                            43541072
# 2                                 257766                            43109193
# 3                                 472186                            40035467
# 4                                 137173                            41167720
# ...                                  ...                                 ...
# 4305                               65218                            34301160
# 4306                              119120                            38264591
# 4307                               74478                            36842285
# 4308                              176590                            33418317
# 4309                               86045                            33316845
#
#       MeanAmplitude_2.356194490192345_1  MeanAmplitude_2.356194490192345_2  \
# 0                              42675142                           21954827
# 1                              45761590                           23541111
# 2                              45296517                           23293852
# 3                              41888839                           21567725
# 4                              43298158                           22265049
# ...                                 ...                                ...
# 4305                           36116430                           18561987
# 4306                           40266947                           20706356
# 4307                           38809960                           19953819
# 4308                           35146446                           18088530
# 4309                           35091896                           18046364
#
#       MeanAmplitude_2.356194490192345_3  class
# 0                              62367472      1
# 1                              61161404      1
# 2                              63474181      1
# 3                              61148415      1
# 4                              64010694      1
# ...                                 ...    ...
# 4305                           61803126      0
# 4306                           62337197      0
# 4307                           59094463      0
# 4308                           60149050      0
# 4309                           58902170      0
#
# [4310 rows x 26 columns]

# %%
normal_scaler = prep.StandardScaler()
scaled_columns = dataframe_project.columns[1:25]
scaled_df = dataframe_project
for col in scaled_columns:
    scaled_df[col] = normal_scaler.fit_transform(scaled_df[col].values.reshape(-1, 1))
scaled_df
# Out:
#                    ImageName  LocalEnergy_0_1  LocalEnergy_0_2  \
# 0     MaI286_255.jpg_0_0.png         0.206364         1.137685
# 1     MaI286_256.jpg_0_0.png         0.817664         1.323767
# 2     MaI286_256.jpg_0_2.png        -0.071022         0.373560
# 3     MaI286_256.jpg_0_3.png         0.224526         1.023026
# 4     MaI286_258.jpg_0_0.png        -0.269428         0.594188
# ...                      ...              ...              ...
# 4305      MaI843_047_0_0.png        -0.143943         0.136845
# 4306      MaI843_048_0_1.png        -0.527516        -0.096267
# 4307      MaI843_048_0_0.png         1.360040         1.403357
# 4308      MaI843_047_0_8.png        -0.045703         1.213713
# 4309      MaI843_049_0_0.png         0.954250         1.392183
#
#       LocalEnergy_0_3  LocalEnergy_0.7853981633974483_1  \
# 0            1.050212                          0.961044
# 1            0.853097                          0.674644
# 2            1.099551                          0.671568
# 3            1.041387                          0.859305
# 4            1.007478                          0.962340
# ...               ...                               ...
# 4305         0.485807                          0.648403
# 4306         0.948370                          0.901621
# 4307         0.929165                          0.889904
# 4308         0.502100                          0.637703
# 4309         0.527001                          0.704976
#
#       LocalEnergy_0.7853981633974483_2  LocalEnergy_0.7853981633974483_3  \
# 0                             0.666561                         -0.787215
# 1                             0.497735                         -0.743263
# 2                             0.458921                         -0.862340
# 3                             0.532372                         -0.657909
# 4                             0.685009                         -0.873417
# ...                                ...                               ...
# 4305                          0.674025                         -0.269214
# 4306                          0.715647                         -0.494143
# 4307                          0.620126                         -0.538403
# 4308                          0.639883                         -0.033262
# 4309                          0.650998                         -0.221823
#
#       LocalEnergy_1.5707963267948966_1  LocalEnergy_1.5707963267948966_2  \
# 0                             0.215413                          1.248537
# 1                             0.810270                          1.219416
# 2                            -0.065256                          1.081344
# 3                             0.232855                          2.600439
# 4                            -0.272901                          0.318206
# ...                                ...                               ...
# 4305                         -0.155585                          0.040035
# 4306                         -0.535561                          0.619319
# 4307                          1.330936                          0.260876
# 4308                         -0.050772                          1.227483
# 4309                          0.943534                          0.396597
#
#       LocalEnergy_1.5707963267948966_3  ...  \
# 0                             0.990115  ...
# 1                             0.800269  ...
# 2                             1.084022  ...
# 3                             0.980256  ...
# 4                             1.069484  ...
# ...                                ...  ...
# 4305                          0.484496  ...
# 4306                          0.931666  ...
# 4307                          0.947406  ...
# 4308                          0.550753  ...
# 4309                          0.516927  ...
#
#       MeanAmplitude_0.7853981633974483_1  MeanAmplitude_0.7853981633974483_2  \
# 0                               1.077631                            1.082246
# 1                               1.286252                            1.289359
# 2                               1.254597                            1.256790
# 3                               1.025223                            1.032650
# 4                               1.118821                            1.120545
# ...                                  ...                                 ...
# 4305                            0.630777                            0.629839
# 4306                            0.912462                            0.913728
# 4307                            0.813567                            0.814113
# 4308                            0.564815                            0.566770
# 4309                            0.561442                            0.562405
#
#       MeanAmplitude_0.7853981633974483_3  MeanAmplitude_1.5707963267948966_1  \
# 0                               0.726466                            0.556098
# 1                               0.676086                            0.527098
# 2                               0.773855                            0.580019
# 3                               0.672973                            0.570229
# 4                               0.797933                            0.597516
# ...                                  ...                                 ...
# 4305                            0.708355                            0.581279
# 4306                            0.725457                            0.611745
# 4307                            0.591175                            0.452550
# 4308                            0.637962                            0.600673
# 4309                            0.585110                            0.497152
#
#       MeanAmplitude_1.5707963267948966_2  MeanAmplitude_1.5707963267948966_3  \
# 0                               1.807526                            1.081326
# 1                               1.847232                            1.289622
# 2                               1.896600                            1.258796
# 3                               4.112539                            1.039405
# 4                               0.650323                            1.120221
# ...                                  ...                                 ...
# 4305                           -0.093301                            0.630111
# 4306                            0.463753                            0.913006
# 4307                            0.002397                            0.811487
# 4308                            1.057681                            0.567096
# 4309                            0.121937                            0.559854
#
#       MeanAmplitude_2.356194490192345_1  MeanAmplitude_2.356194490192345_2  \
# 0                              1.075729                           1.077680
# 1                              1.285047                           1.286934
# 2                              1.253507                           1.254317
# 3                              1.022403                           1.026616
# 4                              1.117981                           1.118603
# ...                                 ...                                ...
# 4305                           0.630928                           0.630116
# 4306                           0.912409                           0.912989
# 4307                           0.813599                           0.813718
# 4308                           0.565145                           0.567660
# 4309                           0.561445                           0.562097
#
#       MeanAmplitude_2.356194490192345_3  class
# 0                              0.730857      1
# 1                              0.680215      1
# 2                              0.777327      1
# 3                              0.679669      1
# 4                              0.799854      1
# ...                                 ...    ...
# 4305                           0.707160      0
# 4306                           0.729585      0
# 4307                           0.593426      0
# 4308                           0.637707      0
# 4309                           0.585351      0
#
# [4310 rows x 26 columns]

# %%
dataframe_scaled_input = scaled_df.iloc[:, 1:25]
dataframe_scaled_output = scaled_df.iloc[:, 25]
scaled_input_train, scaled_input_test, scaled_output_train, scaled_output_test = train_test_split(dataframe_scaled_input, dataframe_scaled_output, test_size=0.3, random_state=42)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
input_train_res, output_train_res = sm.fit_resample(scaled_input_train, scaled_output_train.ravel())

# %%
def correlation(dataset,threshold):
    col_corr=set()
    corr_matrix=dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>threshold:
                colName=corr_matrix.columns[i]
                col_corr.add(colName)
    return col_corr
col=correlation(input_train_res,0.8)
print('Correlated columns:',col)
print(len(col))
# Out:
# Correlated columns: {'LocalEnergy_0.7853981633974483_1', 'MeanAmplitude_1.5707963267948966_3', 'MeanAmplitude_0.7853981633974483_1', 'MeanAmplitude_1.5707963267948966_2', 'MeanAmplitude_0.7853981633974483_3', 'MeanAmplitude_0.7853981633974483_2', 'LocalEnergy_1.5707963267948966_1', 'LocalEnergy_2.356194490192345_3', 'LocalEnergy_2.356194490192345_1', 'MeanAmplitude_0_1', 'MeanAmplitude_1.5707963267948966_1', 'LocalEnergy_1.5707963267948966_3', 'MeanAmplitude_0_3', 'MeanAmplitude_2.356194490192345_3', 'MeanAmplitude_2.356194490192345_1', 'LocalEnergy_0.7853981633974483_2', 'LocalEnergy_2.356194490192345_2', 'MeanAmplitude_0_2', 'MeanAmplitude_2.356194490192345_2'}
# 19

# %%
dataframe_reduced = dataframe_project.drop(columns = ['LocalEnergy_1.5707963267948966_3', 'MeanAmplitude_1.5707963267948966_1', 'MeanAmplitude_1.5707963267948966_2', 'LocalEnergy_1.5707963267948966_2', 'LocalEnergy_0.7853981633974483_2', 'MeanAmplitude_0.7853981633974483_1', 'LocalEnergy_2.356194490192345_3', 'MeanAmplitude_0.7853981633974483_2', 'LocalEnergy_2.356194490192345_1', 'MeanAmplitude_1.5707963267948966_3', 'LocalEnergy_0.7853981633974483_1', 'MeanAmplitude_0_3', 'LocalEnergy_1.5707963267948966_1', 'MeanAmplitude_0_1', 'MeanAmplitude_2.356194490192345_2', 'LocalEnergy_0_2', 'MeanAmplitude_2.356194490192345_3', 'LocalEnergy_2.356194490192345_2', 'MeanAmplitude_0_2'])
dataframe_reduced
# Out:
#                    ImageName  LocalEnergy_0_1  LocalEnergy_0_3  \
# 0     MaI286_255.jpg_0_0.png         0.206364         1.050212
# 1     MaI286_256.jpg_0_0.png         0.817664         0.853097
# 2     MaI286_256.jpg_0_2.png        -0.071022         1.099551
# 3     MaI286_256.jpg_0_3.png         0.224526         1.041387
# 4     MaI286_258.jpg_0_0.png        -0.269428         1.007478
# ...                      ...              ...              ...
# 4305      MaI843_047_0_0.png        -0.143943         0.485807
# 4306      MaI843_048_0_1.png        -0.527516         0.948370
# 4307      MaI843_048_0_0.png         1.360040         0.929165
# 4308      MaI843_047_0_8.png        -0.045703         0.502100
# 4309      MaI843_049_0_0.png         0.954250         0.527001
#
#       LocalEnergy_0.7853981633974483_3  MeanAmplitude_0.7853981633974483_3  \
# 0                            -0.787215                            0.726466
# 1                            -0.743263                            0.676086
# 2                            -0.862340                            0.773855
# 3                            -0.657909                            0.672973
# 4                            -0.873417                            0.797933
# ...                                ...                                 ...
# 4305                         -0.269214                            0.708355
# 4306                         -0.494143                            0.725457
# 4307                         -0.538403                            0.591175
# 4308                         -0.033262                            0.637962
# 4309                         -0.221823                            0.585110
#
#       MeanAmplitude_2.356194490192345_1  class
# 0                              1.075729      1
# 1                              1.285047      1
# 2                              1.253507      1
# 3                              1.022403      1
# 4                              1.117981      1
# ...                                 ...    ...
# 4305                           0.630928      0
# 4306                           0.912409      0
# 4307                           0.813599      0
# 4308                           0.565145      0
# 4309                           0.561445      0
#
# [4310 rows x 7 columns]

# %%
dataframe_scaled_input = dataframe_reduced.iloc[:, 1:6]
dataframe_scaled_output = dataframe_reduced.iloc[:, 6]
scaled_input_train, scaled_input_test, scaled_output_train, scaled_output_test = train_test_split(dataframe_scaled_input, dataframe_scaled_output, test_size=0.3, random_state=42)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
input_train_res, output_train_res = sm.fit_resample(scaled_input_train, scaled_output_train.ravel())
print(output_train_res)
# Out:
# [0 1 0 ... 2 2 2]

# %%
dataframe_final = dataframe_reduced
dataframe_final
# Out:
#                    ImageName  LocalEnergy_0_1  LocalEnergy_0_3  \
# 0     MaI286_255.jpg_0_0.png         0.206364         1.050212
# 1     MaI286_256.jpg_0_0.png         0.817664         0.853097
# 2     MaI286_256.jpg_0_2.png        -0.071022         1.099551
# 3     MaI286_256.jpg_0_3.png         0.224526         1.041387
# 4     MaI286_258.jpg_0_0.png        -0.269428         1.007478
# ...                      ...              ...              ...
# 4305      MaI843_047_0_0.png        -0.143943         0.485807
# 4306      MaI843_048_0_1.png        -0.527516         0.948370
# 4307      MaI843_048_0_0.png         1.360040         0.929165
# 4308      MaI843_047_0_8.png        -0.045703         0.502100
# 4309      MaI843_049_0_0.png         0.954250         0.527001
#
#       LocalEnergy_0.7853981633974483_3  MeanAmplitude_0.7853981633974483_3  \
# 0                            -0.787215                            0.726466
# 1                            -0.743263                            0.676086
# 2                            -0.862340                            0.773855
# 3                            -0.657909                            0.672973
# 4                            -0.873417                            0.797933
# ...                                ...                                 ...
# 4305                         -0.269214                            0.708355
# 4306                         -0.494143                            0.725457
# 4307                         -0.538403                            0.591175
# 4308                         -0.033262                            0.637962
# 4309                         -0.221823                            0.585110
#
#       MeanAmplitude_2.356194490192345_1  class
# 0                              1.075729      1
# 1                              1.285047      1
# 2                              1.253507      1
# 3                              1.022403      1
# 4                              1.117981      1
# ...                                 ...    ...
# 4305                           0.630928      0
# 4306                           0.912409      0
# 4307                           0.813599      0
# 4308                           0.565145      0
# 4309                           0.561445      0
#
# [4310 rows x 7 columns]

# %%
input_final = dataframe_final.iloc[:, 1:6]
output_final = dataframe_final.iloc[:, 6]
final_input_train, final_input_test, final_output_train, final_output_test = train_test_split(input_final, output_final, test_size=0.3, random_state=42)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
input_train_res, output_train_res = sm.fit_resample(final_input_train, final_output_train.ravel())

# %%
# Project data classification rules
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier()
k_range = list(range(1, 21))
param_grid = dict(n_neighbors=k_range)

scores_knn = cross_val_score(knn_model, input_final.values, output_final.values, cv = 10)
start_train_knn = t.time()
grid_search_knn = GridSearchCV(knn_model, param_grid, cv=5, scoring='accuracy', return_train_score=False,verbose=1)
grid_search_knn.fit(input_train_res, output_train_res)
end_train_knn = t.time()
training_time_knn = end_train_knn - start_train_knn
predicted_knn_train = grid_search_knn.predict(input_train_res.values)

start_test_knn = t.time()
predicted_knn_test = grid_search_knn.predict(final_input_test.values)
end_test_knn = t.time()
testing_time_knn = end_test_knn - start_test_knn
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
print("Training data")
print(classification_report(output_train_res, predicted_knn_train))
print("Accuracy: ", accuracy_score(output_train_res, predicted_knn_train))
print("Precision: ", precision_score(output_train_res, predicted_knn_train, average='weighted'))
print("Recall: ", recall_score(output_train_res, predicted_knn_train, average='weighted'))
print("F1-score: ", f1_score(output_train_res, predicted_knn_train, average='weighted'))
print(training_time_knn, 's')
print("Testing data")
print(classification_report(final_output_test, predicted_knn_test))
print("Accuracy: ", accuracy_score(final_output_test, predicted_knn_test))
print("Precision: ", precision_score(final_output_test, predicted_knn_test, average='weighted'))
print("Recall: ", recall_score(final_output_test, predicted_knn_test, average='weighted'))
print("F1-score: ", f1_score(final_output_test, predicted_knn_test, average='weighted'))
print(testing_time_knn, 's')
print(grid_search_knn.best_params_)
print("Mean Accuracy: ",scores_knn.mean())
print("Standard Deviation: ",scores_knn.std())
# Out:
# Training data
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1442
#            1       1.00      1.00      1.00      1442
#            2       1.00      1.00      1.00      1442
#
#     accuracy                           1.00      4326
#    macro avg       1.00      1.00      1.00      4326
# weighted avg       1.00      1.00      1.00      4326
#
# Accuracy:  1.0
# Precision:  1.0
# Recall:  1.0
# F1-score:  1.0
# 5.808979511260986 s
# Testing data
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70       449
#            1       0.74      0.70      0.72       621
#            2       0.36      0.48      0.41       223
#
#     accuracy                           0.65      1293
#    macro avg       0.61      0.62      0.61      1293
# weighted avg       0.67      0.65      0.66      1293
#
# Accuracy:  0.6511987625676721
# Precision:  0.6715663200296668
# Recall:  0.6511987625676721
# F1-score:  0.6593080465802315
# 0.048645734786987305 s
# {'n_neighbors': 1}
# Mean Accuracy:  0.663109048723898
# Standard Deviation:  0.08236364819427856

# %%
sm = SMOTE(random_state=2)
input_total_res, output_total_res = sm.fit_resample(input_final, output_final.ravel())

# %%
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
model_k_means = KMeans()
k_values = range(1, 32)
euclidean_distances = []
for k in k_values:
    k_means_model = KMeans(n_clusters=k)
    k_means_model.fit(input_total_res)
    euclidean_distances.append(k_means_model.inertia_)
plt.plot(k_values, euclidean_distances, 'bx-')
plt.xlabel('K values')
plt.ylabel('Euclidean distances')
plt.title('Elbow curve')
plt.show()
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
start_train_k_means = t.time()
grid_search_k_means = GridSearchCV(model_k_means, param_grid= {'n_clusters': [2, 3, 4, 5, 6]})
grid_search_k_means.fit(input_total_res)
end_train_k_means = t.time()
training_time_k_means = end_train_k_means - start_train_k_means
predicted_k_means_train = grid_search_k_means.predict(input_total_res)
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score
from sklearn.metrics import adjusted_rand_score
print("Training data")
print('Silhouette score: ', silhouette_score(output_total_res.reshape(-1, 1), predicted_k_means_train.reshape(-1 , 1)))
print('DB index: ', davies_bouldin_score(output_total_res.reshape(-1, 1), predicted_k_means_train.reshape(-1 , 1)))
print('ARI score: ', adjusted_rand_score(output_total_res, predicted_k_means_train))
print('Computational time: ', training_time_k_means, 's')
print(grid_search_k_means.best_params_)
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training data
# Silhouette score:  -0.1222923489689501
# DB index:  25.537457025454785
# ARI score:  0.10605163161601903
# Computational time:  2.054230213165283 s
# {'n_clusters': 6}
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
from itertools import product
param_grid = {
    'n_clusters': [2, 3, 4, 5],
    'linkage': [ 'complete', 'average', 'single'],
    'affinity': ['euclidean', 'manhattan', 'cosine']
}
start_train_agglo = t.time()
best_score_agglo = -1
best_params_agglo = {} 
for params in product(*param_grid.values()):
    param_dict = dict(zip(param_grid.keys(), params))
    agg_cluster = AgglomerativeClustering(**param_dict)
    labels = agg_cluster.fit_predict(input_total_res)
    score = silhouette_score(output_total_res.reshape(-1, 1), labels)
    print(f"Parameters: {param_dict}, Silhouette Score: {score}")
    if score > best_score_agglo:
        best_score_agglo = score
        best_params_agglo = param_dict

best_agg_cluster = AgglomerativeClustering(**best_params_agglo)
labels = best_agg_cluster.fit_predict(input_total_res)
end_train_agglo = t.time()
training_time_agglomerative = end_train_agglo - start_train_agglo
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'complete', 'affinity': 'euclidean'}, Silhouette Score: 0.10330315885694508
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'complete', 'affinity': 'manhattan'}, Silhouette Score: 0.10224579093146018
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'complete', 'affinity': 'cosine'}, Silhouette Score: 0.16518653106228048
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'average', 'affinity': 'euclidean'}, Silhouette Score: -0.054514235168061705
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'average', 'affinity': 'manhattan'}, Silhouette Score: -0.054514235168061705
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'average', 'affinity': 'cosine'}, Silhouette Score: 0.16518653106228048
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'single', 'affinity': 'euclidean'}, Silhouette Score: 0.16518653106228048
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'single', 'affinity': 'manhattan'}, Silhouette Score: 0.16518653106228048
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'single', 'affinity': 'cosine'}, Silhouette Score: 0.16518653106228048
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'complete', 'affinity': 'euclidean'}, Silhouette Score: -0.19710393317375083
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'complete', 'affinity': 'manhattan'}, Silhouette Score: -0.20470507467036184
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'complete', 'affinity': 'cosine'}, Silhouette Score: -0.02078925226693367
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'average', 'affinity': 'euclidean'}, Silhouette Score: -0.2328752453463295
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'average', 'affinity': 'manhattan'}, Silhouette Score: -0.16489278611411468
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'average', 'affinity': 'cosine'}, Silhouette Score: -0.014600811763771019
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'single', 'affinity': 'euclidean'}, Silhouette Score: -0.16489278611411468
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'single', 'affinity': 'manhattan'}, Silhouette Score: -0.16489278611411468
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'single', 'affinity': 'cosine'}, Silhouette Score: -0.3514226758596646
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'complete', 'affinity': 'euclidean'}, Silhouette Score: -0.3779478981906433
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'complete', 'affinity': 'manhattan'}, Silhouette Score: -0.39509235339770854
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'complete', 'affinity': 'cosine'}, Silhouette Score: -0.07289918152963674
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'average', 'affinity': 'euclidean'}, Silhouette Score: -0.24455725109485527
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'average', 'affinity': 'manhattan'}, Silhouette Score: -0.20611007074235527
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'average', 'affinity': 'cosine'}, Silhouette Score: -0.1280235759147254
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'single', 'affinity': 'euclidean'}, Silhouette Score: -0.16537751708842394
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'single', 'affinity': 'manhattan'}, Silhouette Score: -0.16537751708842394
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'single', 'affinity': 'cosine'}, Silhouette Score: -0.35109787870984727
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'complete', 'affinity': 'euclidean'}, Silhouette Score: -0.32783194768695256
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'complete', 'affinity': 'manhattan'}, Silhouette Score: -0.35337848119010595
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'complete', 'affinity': 'cosine'}, Silhouette Score: -0.12654856903007067
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'average', 'affinity': 'euclidean'}, Silhouette Score: -0.21672679462498867
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'average', 'affinity': 'manhattan'}, Silhouette Score: -0.21704722037756224
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'average', 'affinity': 'cosine'}, Silhouette Score: -0.1563887196982972
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'single', 'affinity': 'euclidean'}, Silhouette Score: -0.16533804764900242
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'single', 'affinity': 'manhattan'}, Silhouette Score: -0.16533804764900242
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'single', 'affinity': 'cosine'}, Silhouette Score: -0.35109787870984727
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
print("\nBest Parameters: ", best_params_agglo)
print("Best Silhouette Score: ", best_score_agglo)
print('Computational time: ', training_time_agglomerative, 's')
# Out:
# Best Parameters:  {'n_clusters': 2, 'linkage': 'complete', 'affinity': 'cosine'}
# Best Silhouette Score:  0.16518653106228048
# Computational time:  47.91948127746582 s

# %%
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
from itertools import product
param_grid = {
    'min_samples': [2, 3, 4, 5, 6, 7],
    'metric': ['euclidean', 'l1', 'l2', 'manhattan'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
}
start_train_dbscan = t.time()
best_score_dbscan = -1
best_params_dbscan = {}
for params in product(*param_grid.values()):
    param_dict = dict(zip(param_grid.keys(), params))
    dbscan_cluster = DBSCAN(**param_dict)
    labels = dbscan_cluster.fit_predict(input_total_res)
    score = silhouette_score(output_total_res.reshape(-1, 1), labels)
    print(f"Parameters: {param_dict}, Silhouette Score: {score}")
    if score > best_score_dbscan:
        best_score_dbscan = score
        best_params_dbscan = param_dict

best_dbscan_cluster = DBSCAN(**best_params_dbscan)
labels = best_dbscan_cluster.fit_predict(input_total_res)
end_train_dbscan = t.time()
training_time_dbscan = end_train_dbscan - start_train_dbscan
# Out:
# Parameters: {'min_samples': 2, 'metric': 'euclidean', 'algorithm': 'auto'}, Silhouette Score: -0.6960092256731226
# Parameters: {'min_samples': 2, 'metric': 'euclidean', 'algorithm': 'ball_tree'}, Silhouette Score: -0.6960092256731226
# Parameters: {'min_samples': 2, 'metric': 'euclidean', 'algorithm': 'kd_tree'}, Silhouette Score: -0.6960092256731226
# Parameters: {'min_samples': 2, 'metric': 'euclidean', 'algorithm': 'brute'}, Silhouette Score: -0.6960092256731226
# Parameters: {'min_samples': 2, 'metric': 'l1', 'algorithm': 'auto'}, Silhouette Score: -0.9878817256422685
# Parameters: {'min_samples': 2, 'metric': 'l1', 'algorithm': 'ball_tree'}, Silhouette Score: -0.9878817256422685
# Parameters: {'min_samples': 2, 'metric': 'l1', 'algorithm': 'kd_tree'}, Silhouette Score: -0.9878817256422685
# Parameters: {'min_samples': 2, 'metric': 'l1', 'algorithm': 'brute'}, Silhouette Score: -0.9878817256422685
# Parameters: {'min_samples': 2, 'metric': 'l2', 'algorithm': 'auto'}, Silhouette Score: -0.6960092256731226
# Parameters: {'min_samples': 2, 'metric': 'l2', 'algorithm': 'ball_tree'}, Silhouette Score: -0.6960092256731226
# Parameters: {'min_samples': 2, 'metric': 'l2', 'algorithm': 'kd_tree'}, Silhouette Score: -0.6960092256731226
# Parameters: {'min_samples': 2, 'metric': 'l2', 'algorithm': 'brute'}, Silhouette Score: -0.6960092256731226
# Parameters: {'min_samples': 2, 'metric': 'manhattan', 'algorithm': 'auto'}, Silhouette Score: -0.9878817256422685
# Parameters: {'min_samples': 2, 'metric': 'manhattan', 'algorithm': 'ball_tree'}, Silhouette Score: -0.9878817256422685
# Parameters: {'min_samples': 2, 'metric': 'manhattan', 'algorithm': 'kd_tree'}, Silhouette Score: -0.9878817256422685
# Parameters: {'min_samples': 2, 'metric': 'manhattan', 'algorithm': 'brute'}, Silhouette Score: -0.9878817256422685
# Parameters: {'min_samples': 3, 'metric': 'euclidean', 'algorithm': 'auto'}, Silhouette Score: -0.5347732640012983
# Parameters: {'min_samples': 3, 'metric': 'euclidean', 'algorithm': 'ball_tree'}, Silhouette Score: -0.5347732640012983
# Parameters: {'min_samples': 3, 'metric': 'euclidean', 'algorithm': 'kd_tree'}, Silhouette Score: -0.5347732640012983
# Parameters: {'min_samples': 3, 'metric': 'euclidean', 'algorithm': 'brute'}, Silhouette Score: -0.5347732640012983
# Parameters: {'min_samples': 3, 'metric': 'l1', 'algorithm': 'auto'}, Silhouette Score: -0.5449876531614413
# Parameters: {'min_samples': 3, 'metric': 'l1', 'algorithm': 'ball_tree'}, Silhouette Score: -0.5449876531614413
# Parameters: {'min_samples': 3, 'metric': 'l1', 'algorithm': 'kd_tree'}, Silhouette Score: -0.5449876531614413
# Parameters: {'min_samples': 3, 'metric': 'l1', 'algorithm': 'brute'}, Silhouette Score: -0.5449876531614413
# Parameters: {'min_samples': 3, 'metric': 'l2', 'algorithm': 'auto'}, Silhouette Score: -0.5347732640012983
# Parameters: {'min_samples': 3, 'metric': 'l2', 'algorithm': 'ball_tree'}, Silhouette Score: -0.5347732640012983
# Parameters: {'min_samples': 3, 'metric': 'l2', 'algorithm': 'kd_tree'}, Silhouette Score: -0.5347732640012983
# Parameters: {'min_samples': 3, 'metric': 'l2', 'algorithm': 'brute'}, Silhouette Score: -0.5347732640012983
# Parameters: {'min_samples': 3, 'metric': 'manhattan', 'algorithm': 'auto'}, Silhouette Score: -0.5449876531614413
# Parameters: {'min_samples': 3, 'metric': 'manhattan', 'algorithm': 'ball_tree'}, Silhouette Score: -0.5449876531614413
# Parameters: {'min_samples': 3, 'metric': 'manhattan', 'algorithm': 'kd_tree'}, Silhouette Score: -0.5449876531614413
# Parameters: {'min_samples': 3, 'metric': 'manhattan', 'algorithm': 'brute'}, Silhouette Score: -0.5449876531614413
# Parameters: {'min_samples': 4, 'metric': 'euclidean', 'algorithm': 'auto'}, Silhouette Score: -0.25392076405354636
# Parameters: {'min_samples': 4, 'metric': 'euclidean', 'algorithm': 'ball_tree'}, Silhouette Score: -0.25392076405354636
# Parameters: {'min_samples': 4, 'metric': 'euclidean', 'algorithm': 'kd_tree'}, Silhouette Score: -0.25392076405354636
# Parameters: {'min_samples': 4, 'metric': 'euclidean', 'algorithm': 'brute'}, Silhouette Score: -0.25392076405354636
# Parameters: {'min_samples': 4, 'metric': 'l1', 'algorithm': 'auto'}, Silhouette Score: -0.5375758941991097
# Parameters: {'min_samples': 4, 'metric': 'l1', 'algorithm': 'ball_tree'}, Silhouette Score: -0.5375758941991097
# Parameters: {'min_samples': 4, 'metric': 'l1', 'algorithm': 'kd_tree'}, Silhouette Score: -0.5375758941991097
# Parameters: {'min_samples': 4, 'metric': 'l1', 'algorithm': 'brute'}, Silhouette Score: -0.5375758941991097
# Parameters: {'min_samples': 4, 'metric': 'l2', 'algorithm': 'auto'}, Silhouette Score: -0.25392076405354636
# Parameters: {'min_samples': 4, 'metric': 'l2', 'algorithm': 'ball_tree'}, Silhouette Score: -0.25392076405354636
# Parameters: {'min_samples': 4, 'metric': 'l2', 'algorithm': 'kd_tree'}, Silhouette Score: -0.25392076405354636
# Parameters: {'min_samples': 4, 'metric': 'l2', 'algorithm': 'brute'}, Silhouette Score: -0.25392076405354636
# Parameters: {'min_samples': 4, 'metric': 'manhattan', 'algorithm': 'auto'}, Silhouette Score: -0.5375758941991097
# Parameters: {'min_samples': 4, 'metric': 'manhattan', 'algorithm': 'ball_tree'}, Silhouette Score: -0.5375758941991097
# Parameters: {'min_samples': 4, 'metric': 'manhattan', 'algorithm': 'kd_tree'}, Silhouette Score: -0.5375758941991097
# Parameters: {'min_samples': 4, 'metric': 'manhattan', 'algorithm': 'brute'}, Silhouette Score: -0.5375758941991097
# Parameters: {'min_samples': 5, 'metric': 'euclidean', 'algorithm': 'auto'}, Silhouette Score: 0.1183674466318508
# Parameters: {'min_samples': 5, 'metric': 'euclidean', 'algorithm': 'ball_tree'}, Silhouette Score: 0.1183674466318508
# Parameters: {'min_samples': 5, 'metric': 'euclidean', 'algorithm': 'kd_tree'}, Silhouette Score: 0.1183674466318508
# Parameters: {'min_samples': 5, 'metric': 'euclidean', 'algorithm': 'brute'}, Silhouette Score: 0.1183674466318508
# Parameters: {'min_samples': 5, 'metric': 'l1', 'algorithm': 'auto'}, Silhouette Score: -0.2269254693243341
# Parameters: {'min_samples': 5, 'metric': 'l1', 'algorithm': 'ball_tree'}, Silhouette Score: -0.2269254693243341
# Parameters: {'min_samples': 5, 'metric': 'l1', 'algorithm': 'kd_tree'}, Silhouette Score: -0.2269254693243341
# Parameters: {'min_samples': 5, 'metric': 'l1', 'algorithm': 'brute'}, Silhouette Score: -0.2269254693243341
# Parameters: {'min_samples': 5, 'metric': 'l2', 'algorithm': 'auto'}, Silhouette Score: 0.1183674466318508
# Parameters: {'min_samples': 5, 'metric': 'l2', 'algorithm': 'ball_tree'}, Silhouette Score: 0.1183674466318508
# Parameters: {'min_samples': 5, 'metric': 'l2', 'algorithm': 'kd_tree'}, Silhouette Score: 0.1183674466318508
# Parameters: {'min_samples': 5, 'metric': 'l2', 'algorithm': 'brute'}, Silhouette Score: 0.1183674466318508
# Parameters: {'min_samples': 5, 'metric': 'manhattan', 'algorithm': 'auto'}, Silhouette Score: -0.2269254693243341
# Parameters: {'min_samples': 5, 'metric': 'manhattan', 'algorithm': 'ball_tree'}, Silhouette Score: -0.2269254693243341
# Parameters: {'min_samples': 5, 'metric': 'manhattan', 'algorithm': 'kd_tree'}, Silhouette Score: -0.2269254693243341
# Parameters: {'min_samples': 5, 'metric': 'manhattan', 'algorithm': 'brute'}, Silhouette Score: -0.2269254693243341
# Parameters: {'min_samples': 6, 'metric': 'euclidean', 'algorithm': 'auto'}, Silhouette Score: 0.00898476552682976
# Parameters: {'min_samples': 6, 'metric': 'euclidean', 'algorithm': 'ball_tree'}, Silhouette Score: 0.00898476552682976
# Parameters: {'min_samples': 6, 'metric': 'euclidean', 'algorithm': 'kd_tree'}, Silhouette Score: 0.00898476552682976
# Parameters: {'min_samples': 6, 'metric': 'euclidean', 'algorithm': 'brute'}, Silhouette Score: 0.00898476552682976
# Parameters: {'min_samples': 6, 'metric': 'l1', 'algorithm': 'auto'}, Silhouette Score: -0.20441774670982654
# Parameters: {'min_samples': 6, 'metric': 'l1', 'algorithm': 'ball_tree'}, Silhouette Score: -0.20441774670982654
# Parameters: {'min_samples': 6, 'metric': 'l1', 'algorithm': 'kd_tree'}, Silhouette Score: -0.20441774670982654
# Parameters: {'min_samples': 6, 'metric': 'l1', 'algorithm': 'brute'}, Silhouette Score: -0.20441774670982654
# Parameters: {'min_samples': 6, 'metric': 'l2', 'algorithm': 'auto'}, Silhouette Score: 0.00898476552682976
# Parameters: {'min_samples': 6, 'metric': 'l2', 'algorithm': 'ball_tree'}, Silhouette Score: 0.00898476552682976
# Parameters: {'min_samples': 6, 'metric': 'l2', 'algorithm': 'kd_tree'}, Silhouette Score: 0.00898476552682976
# Parameters: {'min_samples': 6, 'metric': 'l2', 'algorithm': 'brute'}, Silhouette Score: 0.00898476552682976
# Parameters: {'min_samples': 6, 'metric': 'manhattan', 'algorithm': 'auto'}, Silhouette Score: -0.20441774670982654
# Parameters: {'min_samples': 6, 'metric': 'manhattan', 'algorithm': 'ball_tree'}, Silhouette Score: -0.20441774670982654
# Parameters: {'min_samples': 6, 'metric': 'manhattan', 'algorithm': 'kd_tree'}, Silhouette Score: -0.20441774670982654
# Parameters: {'min_samples': 6, 'metric': 'manhattan', 'algorithm': 'brute'}, Silhouette Score: -0.20441774670982654
# Parameters: {'min_samples': 7, 'metric': 'euclidean', 'algorithm': 'auto'}, Silhouette Score: 0.007119931265012205
# Parameters: {'min_samples': 7, 'metric': 'euclidean', 'algorithm': 'ball_tree'}, Silhouette Score: 0.007119931265012205
# Parameters: {'min_samples': 7, 'metric': 'euclidean', 'algorithm': 'kd_tree'}, Silhouette Score: 0.007119931265012205
# Parameters: {'min_samples': 7, 'metric': 'euclidean', 'algorithm': 'brute'}, Silhouette Score: 0.007119931265012205
# Parameters: {'min_samples': 7, 'metric': 'l1', 'algorithm': 'auto'}, Silhouette Score: -0.2128334154027714
# Parameters: {'min_samples': 7, 'metric': 'l1', 'algorithm': 'ball_tree'}, Silhouette Score: -0.2128334154027714
# Parameters: {'min_samples': 7, 'metric': 'l1', 'algorithm': 'kd_tree'}, Silhouette Score: -0.2128334154027714
# Parameters: {'min_samples': 7, 'metric': 'l1', 'algorithm': 'brute'}, Silhouette Score: -0.2128334154027714
# Parameters: {'min_samples': 7, 'metric': 'l2', 'algorithm': 'auto'}, Silhouette Score: 0.007119931265012205
# Parameters: {'min_samples': 7, 'metric': 'l2', 'algorithm': 'ball_tree'}, Silhouette Score: 0.007119931265012205
# Parameters: {'min_samples': 7, 'metric': 'l2', 'algorithm': 'kd_tree'}, Silhouette Score: 0.007119931265012205
# Parameters: {'min_samples': 7, 'metric': 'l2', 'algorithm': 'brute'}, Silhouette Score: 0.007119931265012205
# Parameters: {'min_samples': 7, 'metric': 'manhattan', 'algorithm': 'auto'}, Silhouette Score: -0.2128334154027714
# Parameters: {'min_samples': 7, 'metric': 'manhattan', 'algorithm': 'ball_tree'}, Silhouette Score: -0.2128334154027714
# Parameters: {'min_samples': 7, 'metric': 'manhattan', 'algorithm': 'kd_tree'}, Silhouette Score: -0.2128334154027714
# Parameters: {'min_samples': 7, 'metric': 'manhattan', 'algorithm': 'brute'}, Silhouette Score: -0.2128334154027714

# %%
print("\nBest Parameters: ", best_params_dbscan)
print("Best Silhouette Score: ", best_score_dbscan)
print('Computational time: ', training_time_dbscan, 's')
# Out:
# Best Parameters:  {'min_samples': 5, 'metric': 'euclidean', 'algorithm': 'auto'}
# Best Silhouette Score:  0.1183674466318508
# Computational time:  72.33257246017456 s

# %%
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score
from itertools import product

param_grid = {
    'max_iter': [100, 200, 300, 400, 500],
    'covariance_type': ['full', 'tied', 'diag', 'spherical'],
    'n_components': [2, 3, 4, 5, 6],
    'init_params': ['kmeans', 'k-means++', 'random', 'random_from_data']
}

start_train_gmm = t.time()
best_score_gmm = -1
best_params_gmm = {}

for params in product(*param_grid.values()):
    param_dict = dict(zip(param_grid.keys(), params))
    gmm_cluster = GaussianMixture(**param_dict)
    labels = gmm_cluster.fit_predict(input_total_res)
    score = silhouette_score(output_total_res.reshape(-1, 1), labels)
    print(f"Parameters: {param_dict}, Silhouette Score: {score}") 
    if score > best_score_gmm:
        best_score_gmm = score
        best_params_gmm = param_dict

best_gmm_cluster = GaussianMixture(**best_params_gmm)
labels = best_gmm_cluster.fit_predict(input_total_res)
end_train_gmm = t.time()
training_time_gmm = end_train_gmm - start_train_gmm
# Out:
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.17161847292048263
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.03194942053232832
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.03209991029643076
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.04043213156701138
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.032076490410250104
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.056517263246415005
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.10719386128778198
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.1230211922104655
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.15455793967109582
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.12278944223344426
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.20097198524106302
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.18287401397392922
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.1753816359104258
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.1675796644216632
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.17033460130688735
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.18579770176767232
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.27638338401378887
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.0409819796176715
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: -0.009150420388747721
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.006035537359591949
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: 0.00010699529926944996
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: 0.031967816231630176
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.09993588254944495
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.11071188748612086
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.02174345601476576
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.10081029469862977
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.020833257443100682
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.09642986927799878
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.08541114403069988
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.11135996358513217
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.23782000436666592
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.27037997535153707
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.13820214267661457
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.15005919713513832
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.28066321908005015
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.17152428098904607
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.04026266715048748
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.039770819085926515
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.04026266715048748
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.044608926954536124
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.10137172922566623
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.1013483157013831
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.10031321252606361
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.10148815460840481
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.1213599870581862
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.11270650749135527
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.14144432776931828
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.12589639558568366
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.15747396880518683
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.1783258525106313
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.17945857840817983
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.3101457483314658
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16830218483691048
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16830218483691048
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.16830218483691048
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.16830218483691048
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.033503515681893394
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.0334806196519834
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.03349147709221289
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.033225087794267874
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.12037004401215326
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.11982994053225188
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.11869895811849157
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.12087127042199491
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.1583619024420056
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.13618609174902924
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.17161150430499067
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.159052529262611
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.19239671532620198
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.18164416501111424
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.19116617468321281
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.19034532089056977
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.040693405671350824
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.03194942053232832
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.03218323538535787
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.0400045291583799
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: 0.0064869716850721815
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.05663059811186489
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.05645292855206826
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.12758090467559904
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.0991041688111927
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.1199917827491915
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.16491917275339926
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.21314651043932498
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.1773118829617858
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.20965890647000496
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.18963101316893782
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.17610038982705406
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.1664550023281784
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.0437755623126183
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.0811215894486965
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.06227604715567528
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: 0.00010699529926944996
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.06085378107828537
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.07907564423324344
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.07285899586877176
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.02934160512991682
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.10007891669766947
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.09826677336862949
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.08246248152676323
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.08541114403069988
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.09820568339897716
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.26296345803143123
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.20433901468611268
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.13820214267661457
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.11359847816051012
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.26522840916577084
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.30005099335106244
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.04026266715048748
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.039770819085926515
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.04019859223498851
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.04048787982953836
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.10152004431683521
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.09942359750367114
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.10100794723005908
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.09980547764727361
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.12121131650879197
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.1242585540265983
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.14943624041000128
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.1406169435077272
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.15747396880518683
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.16324381558662
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.2284030301182813
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.17648807248440226
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16830218483691048
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16830218483691048
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.16830218483691048
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.16830218483691048
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.033503515681893394
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.033642783384908094
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.033225087794267874
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.03587693888966056
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.12037004401215326
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.1202473981795718
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.1198926129872676
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.16079681751718108
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.1583619024420056
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.1364736369533516
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.15806581153043361
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.1579101317024016
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.18309350494317786
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.19034892144997304
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.20873648814147042
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.20907972981803205
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.040693405671350824
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.03194942053232832
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.04052515097409125
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.04033167351795058
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.035158171279649555
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.056517263246415005
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.1078787948739119
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.12638095646998498
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.10872038682306191
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.12278944223344426
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.16977229790228912
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.21844483041463755
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.1729440160788017
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.16745615460580243
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.25868525134535275
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.25240647093116303
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.16514733326710698
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.04772791979440459
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.10852097403691573
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.1447590460019776
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: 0.00010699529926944996
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: 0.030407385263976117
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.002497156856805497
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.042869182854994095
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.02934160512991682
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.11954689586981859
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.3207190994096311
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.09442714888303859
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.08541114403069988
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.19355115178695428
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.27135216218689634
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.2567096809089955
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.13820214267661457
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.11842938221218062
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.23463556245723013
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.2245177558933862
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.04026266715048748
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.0422756964703261
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.039883262293435355
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.056831749831196154
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.10152004431683521
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.10127786274288307
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.10155559788026826
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.10008831272548015
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.1213599870581862
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.12627276030235107
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.14126757682102326
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.14053739898913817
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.18016242422308507
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.16210245496069575
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.182575379531149
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.27426386122556523
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16830218483691048
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16830218483691048
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.15628936883967828
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.16830218483691048
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.033503515681893394
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.03761710924640657
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.033503515681893394
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.033503515681893394
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.12037004401215326
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.12037004401215326
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.1198926129872676
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.12076008231466502
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.1583619024420056
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.1638147576046064
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.1718138928796414
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.1610701292547553
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.1914051813484878
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.19022766368437116
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.19183533322702095
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.20356789519034846
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.06745616027335402
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.17161847292048263
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.03194942053232832
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.032076490410250104
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.0399110105975291
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.03194942053232832
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.05655445841432067
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.10781644988847504
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.11689011636439368
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.1246931796479164
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.12278944223344426
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.20699641683736505
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.19483484621068187
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.1411206781432813
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.20971317384490748
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.18714836894155434
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.16590491375517968
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.19285363342746764
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.010534126838029345
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: -0.0012796326271158555
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.1472721949675556
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: 0.00010699529926944996
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.025272456613242178
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.12955203590713135
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.17511417139923846
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.02934160512991682
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.19977584935937426
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.18059853728866726
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.11336123990943336
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.08541114403069988
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.10662481684265596
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.28778221401280946
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.2442591309846391
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.19762589557687057
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.08889567624183263
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.22118814775823747
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.2353774260270126
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.04026266715048748
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.05275363105343534
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.04048787982953836
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.04026266715048748
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.10152004431683521
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.10024587697605673
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.10116938307575893
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.1366014527865928
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.1213599870581862
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.12073635948004517
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.161388305268668
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.1601902166291012
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.15842720491419693
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.15509899483206216
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.18112628147778867
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.1763356042252735
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16830218483691048
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16830218483691048
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.16830218483691048
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.09681588669619773
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.033503515681893394
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.033479284329965685
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.033503515681893394
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.033503515681893394
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.12037004401215326
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.11990863881220211
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.1197784475494553
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.16821106475894665
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.15799732772163685
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.15946733277271175
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.13592868163969246
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.1729284616971051
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.19153878022781404
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.19272411148904475
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.18883708087551043
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.21219315339780256
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.06797835955967405
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.040693405671350824
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.03194942053232832
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.03194942053232832
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.04023885177103813
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: 0.007734282400168906
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.05632148979315225
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.12205733325753064
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.11585145534290364
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.11392854977990804
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.12278944223344426
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.203580929115768
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.1952806831553168
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.1848751363014897
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.2253606786214386
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.20219392664202404
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.21867916287487443
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.22516130250531005
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: -0.014684469500582048
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.04120748249789229
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: -0.0037198090056351067
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: 0.00010699529926944996
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.047244414771397125
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.33521690780070806
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.02470125767365163
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.02231609262398707
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: 0.004264449007759809
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.17960396003823884
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.12245940496699821
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.08532220498268323
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.15579516960522447
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.2151786321529865
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.26293154252174106
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.19737009857927326
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.16110769654558044
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.46662918892336286
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.2131481379563754
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.04026266715048748
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.04019859223498851
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.05122755411860511
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.040375475551781864
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.10147996437128462
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.10147996437128462
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.10161377418965784
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.10186477352445633
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.1213599870581862
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.12332740145651887
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.16017882913510095
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.16203153939240558
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.15842720491419693
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.18013948728235166
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.17887658203437054
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.16372081795924406
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16830218483691048
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16830218483691048
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.14951273853459995
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.09658428458536207
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.033503515681893394
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.034331855301860115
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.03296962170072993
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.0336303585153658
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.12037004401215326
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.12046732540605264
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.11941328898547778
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.12069608630839043
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.1583619024420056
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.16153607678782814
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.15857237077809747
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.17372100056576512
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.19239671532620198
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.19144048854719292
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.20884454653607312
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.20911668591210425

# %%
print("\nBest Parameters: ", best_params_gmm)
print("Best Silhouette Score: ", best_score_gmm)
print('Computational time: ', training_time_gmm, 's')
# Out:
# Best Parameters:  {'max_iter': 100, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random_from_data'}
# Best Silhouette Score:  0.17161847292048263
# Computational time:  234.2266480922699 s
